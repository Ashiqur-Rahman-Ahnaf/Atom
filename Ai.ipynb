# %% [markdown]
# Periodic Table 2023

# %%
import pyttsx3

bot = "Science Bot:-"

# initialize the pyttsx3 engine
engine = pyttsx3.init()

from PIL import Image

"""def pic(a):
 # Open the image file
 img = Image.open(a)
 # Show the image
 img.show()"""


def speak(text):
    # set the rate and volume of the speech
    rate = engine.getProperty('rate')
    engine.setProperty('rate', 175)
    volume = engine.getProperty('volume')
    engine.setProperty('volume',1)

    # say the given text
    engine.say(text)
    engine.runAndWait()
       
def Bot(a):
 print(a)
 speak(a)

T = 5
Name = input(speak("what is your name? "))

Bot("wow,I like your name")
Bot(Name)
Bot("Let's larn some thinks new today!")

#Bot("If you don't know how to use me then check out the link below")
#print("https://www.canva.com/design/DAFdcoBnbTw/iQR-nMKODcSVouUx87vrXQ/view?utm_content=DAFdcoBnbTw&utm_campaign=designshare&utm_medium=link&utm_source=publishsharelink")

while T < 10:
 #pic("atom.png")
 ask = input(speak("Enter a Modern Periodic element symbol:- "))
 print()
 print(Name, "input:- ",ask)
 print()
 
 if(ask == "h" or ask == "H" or ask == "1" or ask == "Hydrogen"):
     Bot(bot)
     #pic("H.gif")
     Bot("Hydrogen is the chemical element with the symbol H and atomic number 1.")
     Bot("Hydrogen is the lightest element.")
     Bot("Electronic Configuration: 1")
     Bot("Atomic mass 1.00784 u")
     Bot("He is in Group # 1 due to 1 valence electron.")

 elif(ask == "Stop" or ask == "stop"):
     Bot(bot)
     Bot("Thanks you for use me")
     Bot("Use me again")
     Bot("Bye")
     T = 10

 elif(ask == "He" or ask == "he" or ask == "2" or ask == "Helium"):
     Bot(bot)
     #pic("He.gif")
     Bot("Helium is a chemical element with the symbol He and atomic number 2.")
     Bot("It is a colorless, odorless, tasteless, non-toxic, inert, monatomic gas.")
     Bot("Electronic Configuration: 2")
     Bot("Atomic mass: 4.002602 u")
     Bot("He is in Group # 18 due to 18 valence electron.")
    
 elif(ask == "Li" or ask == "li" or ask == "3" or ask == "Lithium"):
     Bot(bot)
     #pic("Li.gif")
     Bot("Lithium is a chemical element with the symbol Li and atomic number 3.")
     Bot("It is a soft, silvery-white alkali metal.")
     Bot("Electronic Configuration: 2,1")
     Bot("Atomic mass: 6.941 u")
     Bot("Li is in Group # 1 due to 1 valence electron.")
    
 elif(ask == "Be" or ask == "be" or ask == "4" or ask == "Beryllium"):
     Bot(bot)
     #pic("Be.gif")
     Bot("Beryllium is a chemical element with the symbol Be and atomic number 4.")
     Bot("It is a steel-gray, strong, lightweight and brittle alkaline earth metal.")
     Bot("Electronic Configuration: 2,2")
     Bot("Atomic mass: 9.012182 u")
     Bot("Be is in Group # 2 due to 2 valence electron.")
    
 elif(ask == "B" or ask == "b" or ask == "5" or ask == "Boron"):
     Bot(bot)
     Bot("Boron is a chemical element with the symbol B and atomic number 5.")
     Bot("its crystalline form it is a brittle, dark, lustrous metalloid; in its amorphous form it is a brown powder.")
     Bot("Electronic Configuration: 2,3")
     Bot("Atomic mass: 10.811 u")
     Bot("B is in Group # 14 due to 14 valence electron.")
   
 elif(ask == "C" or ask == "c" or ask == "6" or ask == "Carbon"):
     Bot(bot)
     Bot("Carbon is a chemical element with the symbol C and atomic number 6.")
     Bot("It is nonmetallic and tetravalent—its atom making four electrons available to form covalent chemical bonds.")
     Bot("Electronic Configuration: 2,4")
     Bot("Atomic mass: 12.011 u")
     Bot("C is in Group # 13 due to 13 valence electron.")
    
 elif(ask == "N" or ask == "n" or ask == "7" or ask == "Nitrogen"):
     Bot(bot)
     Bot("Nitrogen is the chemical element with the symbol N and atomic number 7.")
     Bot("Nitrogen is a nonmetal and the lightest member of group 15 of the periodic table, often called the pnictogens.")
     Bot("Electronic Configuration: 2,5")
     Bot("Atomic mass: 14.0067 u")
     Bot("N is in Group # 15 due to 15 valence electron.")

 elif(ask == "O" or ask == "o" or ask == "8" or ask == "Oxygen"):
     Bot(bot)
     Bot("Oxygen is the chemical element with the symbol O and atomic number 8")
     Bot("It is a member of the chalcogen group in the periodic table, a highly reactive nonmetal, and an oxidizing agent.")
     Bot("Electronic Configuration: 2,6")
     Bot("Atomic mass: 15.999 u")
     Bot("O is in Group # 16 due to 16 valence electron.")

    
 elif(ask == "F" or ask == "f" or ask == "9" or ask == "Fluorine"):
     Bot(bot)
     Bot("Fluorine is a chemical element with the symbol F and atomic number 9.")
     Bot("It is the lightest halogen and exists at standard conditions as a highly toxic, pale yellow diatomic gas.")
     Bot("Electronic Configuration: 2,7")
     Bot("Atomic mass: 18.998403 u")
     Bot("F is in Group # 17 due to 17 valence electron.")

 elif(ask == "Ne" or ask == "ne" or ask == "10" or ask == "Neon"):
     Bot(bot)
     Bot("Neon is a chemical element with the symbol Ne and atomic number 10.")
     Bot("It is a noble gas. Neon is a colorless, odorless.")
     Bot("Electronic Configuration: 2,8")
     Bot("Atomic mass: 20.1797 u")
     Bot("Ne is in Group # 1 due to 1 valence electron.")

 elif ask == "Na" or ask == "na" or ask == "11" or ask == "Sodium":
    Bot(bot)
    Bot("Sodium is a chemical element with the symbol Na and atomic number 11.")
    Bot("It is a soft, silvery-white, highly reactive metal.")
    Bot("Electronic Configuration: 2,8,1")
    Bot("Atomic mass: 22.989769 u")
    Bot("Na is in Group # 1 due to 1 valence electron.")

 elif ask == "Mg" or ask == "mg" or ask == "12" or ask == "Magnesium":
    Bot(bot)
    Bot("Magnesium is a chemical element with the symbol Mg and atomic number 12.")
    Bot("It is a shiny gray solid which bears a close physical resemblance to the other five elements in the second column (group 2, or alkaline earth metals) of the periodic table: all group 2 elements have the same electron configuration in the outer electron shell and a similar crystal structure.")
    Bot("Electronic Configuration: 2,8,2")
    Bot("Atomic mass: 24.305 u")
    Bot("Mg is in Group # 2 due to 2 valence electrons.")

 elif ask in ["Al", "al", "13", "Aluminum"]:
    Bot(bot)
    Bot("Aluminum is a chemical element with the symbol Al and atomic number 13.")
    Bot("It is a silvery-white, soft, nonmagnetic and ductile metal in the boron group.")
    Bot("Electronic Configuration: 2,8,3")
    Bot("Atomic mass: 26.981538 u")
    Bot("Al is in Group # 13 due to 3 valence electrons.")

 elif ask in ["Si", "si", "14", "Silicon"]:
    Bot(bot)
    Bot("Silicon is a chemical element with the symbol Si and atomic number 14.")
    Bot("It is a hard, brittle crystalline solid with a blue-grey metallic lustre, and is a tetravalent metalloid and semiconductor.")
    Bot("Electronic Configuration: 2,8,4")
    Bot("Atomic mass: 28.085 u")
    Bot("Si is in Group # 14 due to 14 valence electrons.")

 elif ask in ["P", "p", "15", "Phosphorus"]:
    Bot(bot)
    Bot("Phosphorus is a chemical element with the symbol P and atomic number 15.")
    Bot("It is a nonmetal, and is essential for life; it is found in DNA and RNA and is a component of bone.")
    Bot("Electronic Configuration: 2,8,5")
    Bot("Atomic mass: 30.973762 u")
    Bot("P is in Group # 15 due to 15 valence electrons.")

 elif ask in ["S", "s", "16", "Sulfur"]:
    Bot(bot)
    Bot("Sulfur is a chemical element with the symbol S and atomic number 16.")
    Bot("It is abundant, multivalent, and nonmetallic.")
    Bot("Electronic Configuration: 2,8,6")
    Bot("Atomic mass: 32.06 u")
    Bot("S is in Group # 16 due to 16 valence electrons.")

 elif ask in ["Cl", "cl", "17", "Chlorine"]:
    Bot(bot)
    Bot("Chlorine is a chemical element with the symbol Cl and atomic number 17.")
    Bot("It is a yellow-green gas at room temperature.")
    Bot("Electronic Configuration: 2,8,7")
    Bot("Cl is in Group # 17 due to 17 valence electrons.")

 elif(ask == "Ar" or ask == "ar" or ask == "18" or ask == "Argon"):
   Bot(bot)
   Bot("Argon is a chemical element with the symbol Ar and atomic number 18.")
   Bot("It is a colorless, odorless, inert gas that is abundant in the Earth's atmosphere.")
   Bot("Electronic Configuration: 2,8,8")
   Bot("Atomic mass: 39.948 u")
   Bot("Ar is in Group # 18 and is a Noble Gas due to its full valence shell.")

    
 elif(ask == "K" or ask == "k" or ask == "19" or ask == "Potassium"):
  Bot(bot)
  Bot("Potassium is a chemical element with the symbol K and atomic number 19.")
  Bot("It is a soft, silvery-white metal that oxidizes rapidly in air and is highly reactive with water, generating sufficient heat to ignite the hydrogen emitted in the reaction.")
  Bot("Electronic Configuration: 2,8,8,1")
  Bot("Atomic mass: 39.0983 u")
  Bot("K is in Group # 1 due to 1 valence electron.")

 elif(ask == "Ca" or ask == "ca" or ask == "20" or ask == "Calcium"):
  Bot(bot)
  Bot("Calcium is a chemical element with the symbol Ca and atomic number 20.")
  Bot("It is a reactive, soft metal that is a member of the alkaline earth elements.")
  Bot("Electronic Configuration: 2,8,8,2")
  Bot("Atomic mass: 40.078 u")
  Bot("Ca is in Group # 2 due to 2 valence electrons.")    
    
 else:
   Bot(bot)
   Bot("I am learning. Sorry I don't know")
   Bot(Name)
   Bot("Wirte another name.")
# Out:
# wow,I like your name
# Chimri
# Let's larn some thinks new today!
#
# Chimri input:-  C
#
# Science Bot:-
# Carbon is a chemical element with the symbol C and atomic number 6.
# It is nonmetallic and tetravalent—its atom making four electrons available to form covalent chemical bonds.
# Electronic Configuration: 2,4
# Atomic mass: 12.011 u
# C is in Group # 13 due to 13 valence electron.
#
# Chimri input:-  CHimri
#
# Science Bot:-
# I am learning. Sorry I don't know
# Chimri
# Wirte another name.
#
# Chimri input:-  X
#
# Science Bot:-
# I am learning. Sorry I don't know
# Chimri
# Wirte another name.
#
# Chimri input:-  d
#
# Science Bot:-
# I am learning. Sorry I don't know
# Chimri
# Wirte another name.
#
# Chimri input:-  A
#
# Science Bot:-
# I am learning. Sorry I don't know
# Chimri
# Wirte another name.
#
# Chimri input:-  B
#
# Science Bot:-
# Boron is a chemical element with the symbol B and atomic number 5.
# ...
